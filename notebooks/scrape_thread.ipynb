# %%
import re, csv, json, asyncio, time, urllib.parse
from typing import Optional, Dict, List, Tuple
import httpx
from bs4 import BeautifulSoup

# ---------------- CONFIG ----------------
FORUM_BASE   = "https://www.agnoshealth.com"
START_ID     = 1          
MISS_GAP     = 300        # stop after this many consecutive misses AFTER the last hit
CONCURRENCY  = 16         # concurrent requests (tune if needed)
REQ_TIMEOUT  = 25
PAUSE_EACH   = 0.05       # small pause per request for politeness
OUTPUT_JSON  = "agnos_forum_threads.json"
OUTPUT_CSV   = "agnos_forum_threads.csv"

UA = {
    "User-Agent": "AgnosRAGBot/0.6 (+contact: you@example.com)",
    "Accept-Language": "th,en;q=0.8",
}

# ------------- helpers -------------
def clean(s: Optional[str]) -> Optional[str]:
    if s is None: return None
    return re.sub(r"\s+", " ", s).strip() or None

def url_for_id(tid: int) -> str:
    return f"{FORUM_BASE}/forums/{tid}"

def extract_thread_id_from_url(url: str) -> str:
    up = urllib.parse.urlparse(url)
    segs = [s for s in up.path.split("/") if s]
    return segs[-1] if segs else url

def parse_thread_html(html: str, url: str) -> Optional[Dict]:
    """
    Return dict if this is a valid thread page (has either category or title),
    otherwise None. Uses your exact selectors.
    """
    soup = BeautifulSoup(html, "lxml")

    # 1) thread_category: <span class="text-primary_blue-500 line-clamp-1">…</span>
    cat_el = soup.select_one("span.text-primary_blue-500.line-clamp-1")
    thread_category = clean(cat_el.get_text(" ", strip=True)) if cat_el else None

    # 2) title: first <p class="text-sm text-gray-500 line-clamp-3">…</p>
    title = None
    for el in soup.select("p.text-sm.text-gray-500.line-clamp-3"):
        title = clean(el.get_text(" ", strip=True))
        break

    # Not a valid thread if neither marker present
    if not (thread_category or title):
        return None

    # 3) answer_by_doctor: first <p class="mt-4"> after label; else first p.mt-4
    answer_by_doctor = None
    label_node = soup.find(string=re.compile(r"คำตอบโดยแพทย์ผู้เชี่ยวชาญ"))
    if label_node and getattr(label_node, "parent", None):
        after_label_p = label_node.parent.find_next("p", class_="mt-4")
        if after_label_p:
            answer_by_doctor = clean(after_label_p.get_text(" ", strip=True))
    if not answer_by_doctor:
        any_p = soup.find("p", class_="mt-4")
        if any_p:
            answer_by_doctor = clean(any_p.get_text(" ", strip=True))

    out = {
        "url": url,
        "thread_id": extract_thread_id_from_url(url),
        "title": title,
        "thread_category": thread_category,
        "answer_by_doctor": answer_by_doctor,
    }
    out["title_category"] = clean(f"{title or ''} {thread_category or ''}")
    return out


# ------------- save utils -------------
def save_json(data: List[Dict], path: str):
    with open(path, "w", encoding="utf-8") as f:
        json.dump(data, f, ensure_ascii=False, indent=2)

def save_csv(data: List[Dict], path: str):
    fields = ["url","thread_id","title","thread_category","answer_by_doctor","title_category"]
    with open(path, "w", newline="", encoding="utf-8") as f:
        w = csv.DictWriter(f, fieldnames=fields)
        w.writeheader()
        for row in data:
            w.writerow({k: row.get(k) for k in fields})



# ------------- async HTTP -------------
async def fetch_text(client: httpx.AsyncClient, url: str) -> Optional[str]:
    try:
        r = await client.get(url, timeout=REQ_TIMEOUT, follow_redirects=True)
        if r.status_code != 200:
            return None
        return r.text
    except Exception:
        return None

async def fetch_and_parse(client: httpx.AsyncClient, tid: int) -> Optional[Dict]:
    url = url_for_id(tid)
    html = await fetch_text(client, url)
    if not html:
        return None
    return parse_thread_html(html, url)


# ------------- forward scan with miss-streak stop -------------
CHECKPOINT_EVERY_HITS = 50     # write partial JSON every N hits
HEARTBEAT_SECS        = 3.0    # print progress every N seconds
VERBOSE_HIT_LOGS      = True   # print a short line for each hit (can set False to quiet)

async def scan_all_threads(start_id: int = START_ID, miss_gap: int = MISS_GAP, concurrency: int = CONCURRENCY) -> List[Dict]:
    """
    Scan IDs upward from start_id. Stop after `miss_gap` consecutive misses *after* the last hit.
    Emits periodic progress and checkpoints.
    """
    results: List[Dict] = []
    last_hit_id = 0
    miss_streak = 0
    next_id = start_id
    processed = 0
    hits = 0
    t0 = time.time()
    last_beat = t0
    last_proc = 0

    sem = asyncio.Semaphore(concurrency)
    running: set[asyncio.Task] = set()
    lock = asyncio.Lock()              # to serialize console output/checkpoints
    stop_event = asyncio.Event()

    async with httpx.AsyncClient(headers=UA) as client:
        async def worker(tid: int):
            nonlocal last_hit_id, miss_streak, processed, hits
            async with sem:
                await asyncio.sleep(PAUSE_EACH)
                url = url_for_id(tid)
                html = await fetch_text(client, url)
                parsed = parse_thread_html(html, url) if html else None

                async with lock:
                    processed += 1
                    if parsed is not None:
                        # hit
                        hits += 1
                        if tid > last_hit_id:
                            last_hit_id = tid
                            miss_streak = 0
                        if VERBOSE_HIT_LOGS:
                            cat = (parsed.get("thread_category") or "")[:40]
                            ttl = (parsed.get("title") or "")[:40]
                            print(f"[hit] id={tid} cat='{cat}' title='{ttl}'")
                        # checkpoint
                        results.append(parsed)
                        if hits % CHECKPOINT_EVERY_HITS == 0:
                            save_json(results, "agnos_forum_threads_partial.json")
                    else:
                        # miss
                        if tid > last_hit_id:
                            miss_streak += 1

        async def heartbeat():
            nonlocal last_beat, last_proc
            while not stop_event.is_set():
                await asyncio.sleep(HEARTBEAT_SECS)
                async with lock:
                    now = time.time()
                    dt = now - last_beat
                    delta_proc = processed - last_proc
                    rps = (delta_proc / dt) if dt > 0 else 0.0
                    print(f"[{now - t0:6.1f}s] next_id={next_id} last_hit={last_hit_id} "
                          f"hits={hits} processed={processed} miss_streak={miss_streak} ~{rps:.1f} req/s")
                    last_beat, last_proc = now, processed

        hb_task = asyncio.create_task(heartbeat())

        # launch in bursts; stop when post-max miss gap reached
        try:
            while True:
                burst = []
                async with lock:
                    # stop condition (post-max gap)
                    if last_hit_id and (next_id - 1 - last_hit_id) >= miss_gap:
                        break
                for _ in range(concurrency * 8):
                    async with lock:
                        # stop condition inside loop too
                        if last_hit_id and (next_id - 1 - last_hit_id) >= miss_gap:
                            break
                        tid = next_id
                        next_id += 1
                    t = asyncio.create_task(worker(tid))
                    running.add(t)
                    t.add_done_callback(running.discard)
                if running:
                    await asyncio.gather(*list(running))
                    running.clear()
                else:
                    # nothing running -> done
                    break
        finally:
            stop_event.set()
            await hb_task

    # final sort & return
    results.sort(key=lambda r: int(r["thread_id"]))
    return results


async def run_full_scan_async():
    print(f"Scanning from id {START_ID} with miss gap {MISS_GAP} and concurrency {CONCURRENCY} …")
    t0 = time.time()
    rows = await scan_all_threads(start_id=START_ID, miss_gap=MISS_GAP, concurrency=CONCURRENCY)
    dt = time.time() - t0
    print(f"\nFound {len(rows)} threads in {dt:.1f}s.")
    if rows:
        print(f"ID range covered: {rows[0]['thread_id']} → {rows[-1]['thread_id']}")
        print("Sample row:")
        print(json.dumps(rows[0], ensure_ascii=False, indent=2))
    save_json(rows, OUTPUT_JSON)
    save_csv(rows, OUTPUT_CSV)
    print(f"\nSaved JSON: {OUTPUT_JSON}")
    print(f"Saved CSV : {OUTPUT_CSV}")
    return rows

# %%
rows = await run_full_scan_async()
# Out:
# Scanning from id 1 with miss gap 300 and concurrency 16 …
# [hit] id=9 cat='ขี้หูอุดตัน (Impacted cerumen)' title='มีอาการได้เสียงกรอบแกลบในหูมั้ยมีอาการเจ'
# [hit] id=16 cat='ภาวะการปรับตัวผิดปกติ (Adjustment disord' title='ทำแบบสอบถามเดือนละครั้งนี่ครั้งที่3แล้วค'
# [hit] id=14 cat='เยื่อหุ้มหัวใจอักเสบ (Acute pericarditis' title='สวัสดีค่ะ หนูมีอาการเจ็บแน่นหน้าอกเหมือน'
# [hit] id=8 cat='ผื่นตามร่างกาย (Dermatitis unspecified)' title='สวัสดีค่ะคุณหมอ รบกวนสอบถามหน่อยค่ะว่า น'
# [hit] id=10 cat='ภาวะผิดปกติที่เกิดจากสารเสพติด (Substanc' title='ผู้ป่วยโรคนี้ต้องรักษาด้วยวิธีไหนคะ'
# [hit] id=7 cat='การอักเสบของอุ้งเชิงกราน (Pelvic inflamm' title='ประจำเดือนไม่มาเกือบ3เดือน แต่ตรวจขึ้นขี'
# [hit] id=1 cat='ผื่นตามร่างกาย (Dermatitis unspecified)' title='เป็นคล้ายๆผดผื่นที่ก้นค่ะน้อง9เดือน ผดนู'
# [   3.3s] next_id=129 last_hit=16 hits=7 processed=8 miss_streak=0 ~2.4 req/s
# [hit] id=6 cat='ผื่นตามร่างกาย (Dermatitis unspecified)' title='เวลาหลังอาบน้ำทุกครั้ง(ยกเว้นอาบน้ำจากเค'
# [hit] id=11 cat='กรดไหลย้อน (GERD)' title='เป็นบ่อยมากค่ะบางทีจุกถึงคอ เเต่อาการตอน'
# [hit] id=15 cat='ภาวะประจำเดือนมาน้อยผิดปกติ (Oligomenorr' title='คือหนูมีประจำเดือนมาเล็กๆน้อยสีน้ำตาลแบบ'
# [hit] id=12 cat='ผื่นตามร่างกาย (Dermatitis unspecified)' title='เป็นผื่นปื้นตามเเขน คัน มีขึ้นที่มือด้วย'
# [hit] id=13 cat='ไข้หวัด (Common cold (Nasopharyngitis))' title='ผายลมทั้งวัน เกิดจากสาเหตุอะไรคะ แล้วผิด'
# [hit] id=3 cat='สงสัยภาวะตั้งครรภ์ (Pregnancy not yet co' title='ประจำเดือนไม่มาประมาณ5-6เดือนไปตรวจที่โร'
cat='เสี่ยงต่อโรคซึมเศร้า (Major depressive d' title='โรคนี้ทำอย่างไรหายเครียดและก็หายกดดันได้'
# [  21.3s] next_id=129 last_hit=102 hits=93 processed=126 miss_streak=11 ~11.7 req/s
# [  24.3s] next_id=257 last_hit=102 hits=93 processed=130 miss_streak=15 ~1.3 req/s
# [hit] id=140 cat='เสี่ยงต่อโรคซึมเศร้า (Major depressive d' title='ตอนนี้รู้สึกเเย่มาก'
# [hit] id=133 cat='ไซนัสอักเสบ (Acute non-bacterial sinusit' title='หนูมีอาการปวดหัวมาได้ระยะหนึ่ง(ประมาณ1สั'
# [hit] id=136 cat='คอหอยอักเสบ (Non-bacterial pharyngotonsi' title='เจ็บคอมาตั้งแต่วันที่25 สิงหา จนตอนนี้18'
# [hit] id=149 cat='ภาวะประจำเดือนมาน้อยผิดปกติ (Oligomenorr' title='มีคำแนะนำเพิ่มเติมไหมค่ะ'
# [hit] id=145 cat='กระเพาะอาหารอักเสบ (Dyspepsia)' title='สวัสดีค่ะ มีอาการแสบท้องแบบรู้สึกว่ามีน้'
# [hit] id=134 cat='ภาวะการปรับตัวผิดปกติ (Adjustment disord' title='อารมอ่อนไหวง่าย เวลาร้องไห้ หรือเครียด จ'
# [hit] id=151 cat='กระเพาะปัสสาวะอักเสบ (Cystitis)' title='ลองสังเกตุปัสสาวะตัวเองค่ะ ลองฉายไฟขึ้นม'
# [hit] id=137 cat='โรคนอนไม่หลับ (Insomnia)' title='นอนไม่หลับเวลามีคนนอนด้วย ทั้งที่เป็นคนใ'
# [  27.3s] next_id=257 last_hit=151 hits=101 processed=142 miss_streak=0 ~4.0 req/s
# [hit] id=135 cat='เต้านมอักเสบ (Mastitis)' title='เคยให้นมบุตรมาก่อน ปัจจุบันหย่านมมาประมา'
# [hit] id=150 cat='ปวดศีรษะจากความเครียด (Tension Headache)' title='อยากทราบว่าเป็นอะไร เวียนหัว ปวดต่นคอลาม'
# [hit] id=139 cat='หลอดลมอักเสบ (Acute Bronchitis)' title='เวลานอนหายใจมีเสีนงครืดคราด หายใจแรงไอบ้'
# [hit] id=138 cat='คอหอยอักเสบ (Non-bacterial pharyngotonsi' title='เจ็บภายในคอเวลากลืนน้ำลายยังรู้สึกถึงเจ็'
# [hit] id=142 cat='เสี่ยงต่อโรคทางอารมณ์ที่มีภาวะแทรกซ้อน (' title='รู้สึกโทษตัวเองมากๆ มาเป็นเวลานาน ซึมทั้'
# [hit] id=146 cat='กล้ามเนื้ออักเสบ (Muscle strain)' title='มีอาการปวดเมื่อยช่วงเอวด้านซ้าย ช่วงก้นแ'
# [hit] id=154 cat='เสี่ยงต่อโรคอารมณ์สองขั้ว (Bipolar disor' title='พักหลังเริ่มมีอาการหน้ามืดบ่อยๆ ชอบร้องไ'
# [hit] id=152 cat='ออฟฟิศซินโดรม (Office syndrome)' title='ปวดท้ายทอยด้านซ้ายร้าวมาที่ข้างในหูค่ะ ป'
# [hit] id=148 cat='ภาวะการปรับตัวผิดปกติ (Adjustment disord' title='หนูมีอาการนอนละเมอร่วมด้วย'
# [hit] id=157 cat='กระเพาะอาหารอักเสบ (Dyspepsia)' title='สวัสดีค่ะ รบกวนสอบถามหลังจากรักษากรดไหลย'
cat='เสี่ยงต่อโรคซึมเศร้า (Major depressive d' title='ควรไปหาหมอดีไหมค่ะ'
# [hit] id=190 cat='ถุงน้ำรังไข่ (PCOS)' title='หนูสามารถมีลูกได้มั้ย'
# [hit] id=196 cat='เสี่ยงต่อโรคทางอารมณ์ที่มีภาวะแทรกซ้อน (' title='ฉันเป็นโรคอะไร'
# [hit] id=199 cat='เสี่ยงต่อโรคอารมณ์สองขั้ว (Bipolar disor' title='เคยหาหมอหมอวิเคราะห์ว่าเป็นซึมเศร้าอ่ะค่'
# [hit] id=203 cat='กรดไหลย้อน (GERD)' title='มีอาการท้องอืด ปวดท้องบ้าง แต่มีอาการเกร'
# [hit] id=194 cat='เสี่ยงต่อโรคซึมเศร้า (Major depressive d' title='หนูเป็นคนคิดมาก คิดซ้ำวนไปวนมา เก็บคำพูด'
# [hit] id=201 cat='แผลริมอ่อน (Chancroid)' title='เคยไปตรวจมาแล้วค่ะ พบว่าเป็นฝีที่บริเวณอ'
# [  39.3s] next_id=257 last_hit=203 hits=155 processed=201 miss_streak=0 ~4.3 req/s
# [hit] id=206 cat='เสี่ยงต่อโรคทางอารมณ์ที่มีภาวะแทรกซ้อน (' title='จริงๆแล้วป่วยเป็นโรคไบโพล่าร์ พบแพทย์ครั'
# [hit] id=193 cat='ภาวะท้องนอกมดลูก (Ectopic pregnancy)' title='เคยแท้งมาแล้ว1คนค่ะแล้วประมาณเดือนกว่าแล'
# [hit] id=207 cat='ลำไส้อักเสบ (Non-bacterial gastroenterit' title='ทำไมลำไส้อักเสบหายแล้ว อาหารที่เคยทานไม่'
# [hit] id=205 cat='ภาวะแพ้ชนิดรุนแรง (Anaphylaxis)' title='หลังจากหาย covid อาการภูมิแพ้ มีมากขึ้นแ'
# [hit] id=202 cat='เสี่ยงต่อโรควิตกกังวล (Anxiety disorder)' title='เจ็บหน้าอกแปร้บๆ เสี่ยงต่อโรคหัวใจไหมครั'
# [hit] id=214 cat='เสี่ยงต่อโรควิตกกังวล (Anxiety disorder)' title='มีทานยาลดความดันกับลดไขมัน ที่ทานประจำค่'
# [hit] id=209 cat='ปวดศีรษะไมเกรน (Migraine)' title='เราเคยปวดหัวแบบนี้มารวมครั้งนี้เป็นเราเค'
# [hit] id=208 cat='เสี่ยงต่อโรคอารมณ์สองขั้ว (Bipolar disor' title='ควรเริ่มรักษายังไงค่ะ'
# [hit] id=211 cat='กล้ามเนื้ออักเสบ (Muscle strain)' title='มีรอยช้ำขึ้นที่ขาเยอะมาก ขึ้นมาเองตลอดไม'
# [hit] id=204 cat='เสี่ยงต่อโรคซึมเศร้า (Major depressive d' title='ต้องรักษายังไงครับ'
# [hit] id=210 cat='ท้องผูก (Constipation (unspecified))' title='มีอาารท้องผูกเรื้อรังมานานมากค่ะ จนปัจจุ'
# [hit] id=215 cat='ภาวะการปรับตัวผิดปกติ (Adjustment disord' title='มีอารมณ์ เบื่อ หรือ ภาวะหมดไฟ กับงาน ประ'
# [hit] id=216 cat='ผิวหนังอักเสบเรื้อรัง (Chronic eczema)' title='ผิวแพ้ง่าย คันคามร่างกาย เปนรอยแดง พอใช้'
# [  42.4s] next_id=257 last_hit=216 hits=168 processed=215 miss_streak=0 ~4.6 req/s
# [hit] id=219 cat='ไข้หวัด (Common cold (Nasopharyngitis))' title='มีไข้ ไอมีเสมหะ น้ำมูกใส เป็นหวัดหรือป่า'
# [hit] id=220 cat='กรดไหลย้อน (GERD)' title='มีอาการเจ็บหน้าอกแปล๊บๆจี๊ดๆส่วนมากเป็นท'
# [hit] id=221 cat='ลำไส้อักเสบ (Non-bacterial gastroenterit' title='มีอาการคลื่นไส้หลังกิอาหารบางมื้อ อาเจีย'
# [hit] id=224 cat='เสี่ยงต่อโรคอารมณ์สองขั้ว (Bipolar disor' title
# [hit] id=270 cat='เนื้องอกกระดูกสันหลัง (Tumor of spine)' title='ผมปวดบริเวณกระดูกสันหลังมา 3 ปีแล้ว หาสา'
# [hit] id=273 cat='กระเพาะอาหารอักเสบ (Dyspepsia)' title='หนูมีอาการปวดจุกแน่นลิ้นปี่ พอกดแล้วเจ็บ'
# [hit] id=271 cat='เสี่ยงต่อโรคซึมเศร้า (Major depressive d' title='คิดมาก เครียด คิดฆ่าตัวเองบ่อยครั้ง โดนค'
# [hit] id=272 cat='เวียนศีรษะ (Dizziness (unspecified))' title='จู่ๆก็เวียนศีรษะ และปวดศีรษะหลังด้านล่าง'
# [hit] id=275 cat='เสี่ยงต่อโรคทางอารมณ์ที่มีภาวะแทรกซ้อน (' title='เสี่ยงต่อโรคทางอารมณ์ที่มีภาวะแทรกซ้อน 6'
# [hit] id=264 cat='การอักเสบของอุ้งเชิงกราน (Pelvic inflamm' title='ปวดท้องน้อยมา9วันแล้วค่ะ 2วันหลังมาคือทร'
# [hit] id=274 cat='เสี่ยงต่อโรควิตกกังวล (Anxiety disorder)' title='ผมทำแบบสอบถามแล้วขึ้นวิตกกังวล ดูอาการแล'
# [hit] id=258 cat='ภาวะหมดประจำเดือน/วัยทอง (Menopause)' title='มีน้ำไหลจากช่องค ลอดมืาก'
# [hit] id=269 cat='เต้านมอักเสบ (Mastitis)' title='มีก้อนที่รักเเร้สัเกตุได้เเต่คลำไ่ม่พบก้'
# [hit] id=281 cat='เสี่ยงต่อโรคทางอารมณ์ที่มีภาวะแทรกซ้อน (' title='อ่านของหนูให้จบนะคะ เป็นอาการแบบนี้มา4ปี'
# [hit] id=282 cat='ออฟฟิศซินโดรม (Office syndrome)' title='คือ ช่วงที่ผ่านมาผมทำงานหนัก นั่งอยู่หน้'
# [hit] id=283 cat='ปวดศีรษะจากความเครียด (Tension Headache)' title='ถ้าคนที่บ้านเป็นโควิดแล้วเราปวดหัวกินยาพ'
# [  57.4s] next_id=385 last_hit=283 hits=226 processed=279 miss_streak=0 ~6.7 req/s
# [hit] id=267 cat='เสี่ยงต่อโรคซึมเศร้า (Major depressive d' title='ทำแบบทดสอบแล้วมีกราฟขึ้นว่า เสี่ยงต่อโรค'
# [hit] id=278 cat='เสี่ยงต่อโรคอารมณ์สองขั้ว (Bipolar disor' title='ถ้าเป็นแบบอารมณ์ตอนกลางคืนคือดิ่งมากๆๆๆร'
# [hit] id=279 cat='ไส้ติ่งอักเสบ (Appendicitis)' title='คือไปหาหมอ3โรงพยาบาลแล้วค่ะ หมอที่ไปหาคร'
# [hit] id=285 cat='เสี่ยงต่อโรคทางอารมณ์ที่มีภาวะแทรกซ้อน (' title='อาการร้องไห้ง่าย หวั่นไหวง่ายมากๆ ใครพูด'
# [hit] id=277 cat='มะเร็งต่อมน้ำเหลือง (Lymphoma)' title='มีก้อนนูนๆวงกลมอยู่ตรงขมับ กดแล้วเจ็บเป็'
# [hit] id=276 cat='เสี่ยงต่อโรคซึมเศร้า (Major depressive d' title='อยากจะทราบว่าต้องกินยาอะไรเเล้ว55%นี้คือ'
# [hit] id=293 cat='เสี่ยงต่อโรคทางอารมณ์ที่มีภาวะแทรกซ้อน (' title='ร้องไห้ง่ายมาตั้งแต่เด็ก…คำพูดทุกคนที่พู'
# [  60.4s] next_id=385 last_hit=293 hits=233 processed=287 miss_streak=0 ~2.7 req/s
# [hit] id=301 cat='เสี่ยงต่อโรคทางอารมณ์ที่มีภาวะแทรกซ้อน (' title='ควรทำอย่างไรดีคะ รู้สึกว่าตัวเองคิดลบอยู'
# [hit] id=299 cat='เสี่ยงต่อโรคซึมเศร้า (Major depressive d' title
cat='เสี่ยงต่อโรคซึมเศร้า (Major depressive d' title='โรงพยาบาลกระทุ่มแบนมีหมอเฉพาะทางไหมคะแล้'
# [hit] id=326 cat='ปวดท้องประจำเดือน (Dysmenorrhea unpecifi' title='เป็นประจำเดือนแล้วมีเลือดไหลเป็นสีน้ำตาล'
# [hit] id=304 cat='กระเพาะปัสสาวะอักเสบ (Cystitis)' title='คือ ตอนแรกผมมีอาการปัสสาวะบ่อยมากในแต่ล่'
# [hit] id=328 cat='ภาวะผิวแห้ง (Xerosis cutis (Dry skin))' title='เป็นตุ่มเม็ดขึ้นทั่วตามร่างกาย เป็นเม็ด '
# [hit] id=320 cat='ภาวะการปรับตัวผิดปกติ (Adjustment disord' title='ลองอ่านจากการรักษาดเเล้ว้วยตนเองเเล้วก็เ'
# [hit] id=330 cat='ภาวะการปรับตัวผิดปกติ (Adjustment disord' title='อารมหงุดหงิดง่าย ค่ะเวลาคนอื่นพูดบูลี่ ห'
# [hit] id=314 cat='เสี่ยงต่อโรควิตกกังวล (Anxiety disorder)' title='สวัสดีค่ะ พอดีเป็นแพนิคเวลาต้องเดินทางอย'
# [hit] id=322 cat='ท้องอืด (Bloating (unspecified))' title='มีอาการท้องอืด หลังจากรับประทานอาหารเสร็'
# [hit] id=316 cat='เสี่ยงต่อโรคซึมเศร้า (Major depressive d' title='เหตุเกิดของความเครียดความระแวง เกิดจากแฟ'
# [  69.4s] next_id=385 last_hit=330 hits=266 processed=321 miss_streak=0 ~3.3 req/s
# [hit] id=321 cat='เสี่ยงต่อโรคอารมณ์สองขั้ว (Bipolar disor' title='ต้องทำยังไง หรือรักษายังไงค่ะ'
# [hit] id=318 cat='โรคหลอดเลือดหัวใจ (Stable coronary arter' title='ตามข้อมูลในแบบสอบถามนะครับ ข้อมูลเพิ่ม ผ'
# [hit] id=323 cat='เสี่ยงต่อโรคซึมเศร้า (Major depressive d' title='หมอคะ พอดีว่าหนูไปเสี่ยงมา ตรวจ HIV ด้วย'
# [hit] id=333 cat='กระเพาะอาหารอักเสบ (Dyspepsia)' title='รู้สึกจุกแน่นลิ้นปี่มาสัก 3-4 เดือนแล้ว '
# [hit] id=311 cat='เสี่ยงต่อโรคซึมเศร้า (Major depressive d' title='รู้สึกว่าถูกกดดันจากครอบครัวแล้วก็เรื่อง'
# [hit] id=319 cat='ภาวะการปรับตัวผิดปกติ (Adjustment disord' title='ผิดปกติในทางไหนคะแร้วพอมีแนวทางรักษาแบบไ'
# [hit] id=327 cat='อัณฑะอักเสบ (Epididymo-orchitis)' title='มีเม็ดเหมือนสิวตรงอัณฑะข้างซ้ายบีบออกมาแ'
# [hit] id=325 cat='ท้องผูก (Constipation (unspecified))' title='สวัสดีค่ะสอบถามหน่อยค่ะ น้อง อายุ1เดือน4'
# [hit] id=332 cat='โรคนอนไม่หลับ (Insomnia)' title='มีอาการนอนหลับไม่สนิทครับ หรือบางวันก็นอ'
# [hit] id=324 cat='ผิวหนังอักเสบเรื้อรัง (Chronic eczema)' title='สวัสดีค่ะ หนูต้องปรับเปลียนพฤติกรรม การก'
# [hit] id=329 cat='เสี่ยงต่อโรคทางอารมณ์ที่มีภาวะแทรกซ้อน (' title='คือช่วงนี้อารมณ์โมโหง่่ย เยื่อ อยากจะทำอ'
# [hit] id=337 cat='หลอดลมอักเสบ (Acute Bronchitis)' title='ไปหากมอที่คลินิคมาค่ะ ได้ยามาทาน 3 ตัว ม'
# [hit] id=334 cat='เสี่ยงต่อโรคอารมณ์สองขั้ว (Bipolar disor' title
cat='เสี่ยงต่อโรคทางอารมณ์ที่มีภาวะแทรกซ้อน (' title='รู้สึกเหมือนตัวเองจะเป็น Burnout Syndrom'
# [hit] id=367 cat='กล้ามเนื้ออักเสบ (Muscle strain)' title='หกล้ม ใช้มือค้ำทำให้ปวดแขนท่อนล่างก่อนถึ'
# [hit] id=376 cat='ไข้เลือดออกที่มีอาการรุนแรง (Dengue hemo' title='เบื้องต้นถ้ายังไม่ได้ไปพบแพทย์ ต้องปฎิบั'
# [hit] id=369 cat='เสี่ยงต่อโรคทางอารมณ์ที่มีภาวะแทรกซ้อน (' title='คือเราเครียดกับปัญหา​จากครอบครัวโดนกดดัน'
# [hit] id=366 cat='เสี่ยงต่อโรคซึมเศร้า (Major depressive d' title='ผมอยากรักษาแบบไม่ใช้ยาแต่ทางบ้านต้องการใ'
# [  78.4s] next_id=385 last_hit=376 hits=303 processed=370 miss_streak=0 ~3.7 req/s
# [hit] id=373 cat='ภาวะการปรับตัวผิดปกติ (Adjustment disord' title='นอนหลับไม่สนิทมักจะตื่นขึ้นมา2-3ชั่วโมง '
# [hit] id=378 cat='ลำไส้อักเสบ (Non-bacterial gastroenterit' title='อยากทราบว่าเป็นอะไรกันแน่ค่ะ ปวดบิดปวดแส'
# [hit] id=374 cat='ภาวะสับสนเฉียบพลัน (Delirium)' title='ดิฉันพบว่ามีความอ่อนเพลีย หรือ อาการนอนไ'
# [hit] id=364 cat='ภาวะการปรับตัวผิดปกติ (Adjustment disord' title='สวัสดีครับบบ'
# [hit] id=372 cat='ภาวะการปรับตัวผิดปกติ (Adjustment disord' title='มีอาการกังวล ตัวสั่น ใจหวิว เหมือนจะร้อง'
# [hit] id=370 cat='เส้นประสาทการทรงตัวอักเสบ (Vestibular ne' title='สวัสดีค่ะหมอ หนูมีอาการเวียนหัว มึนๆที่ห'
# [hit] id=377 cat='ไข้เฉียบพลัน ที่อาการยังไม่แน่ชัด (Acute' title='วันนี้มีอาการจะอาเจียนและไข้ขึ้นนิดหน่อย'
# [hit] id=375 cat='เสี่ยงต่อโรคอารมณ์สองขั้ว (Bipolar disor' title='ผมนอนเหมือนไม่ได้นอนเลยครับ รู้สึกตัวตลอ'
# [hit] id=384 cat='เบาหวาน (Diabetes mellitus)' title='ทำไมอาการของผมคล้ายเบาหวาน น้ำหนักก็ปกติ'
# [hit] id=381 cat='ไส้เลื่อนขาหนีบ (Uncomplicated inguinal ' title='ผมมีก้อนใกล้ๆรูทวารระหว่างอัณฑะกับรูทวาร'
# [hit] id=379 cat='เสี่ยงต่อโรคซึมเศร้า (Major depressive d' title='เครียดมากค่ะมีวิธีไหนแก้ได้ไหมคะ โดนไล่อ'
# [hit] id=383 cat='เสี่ยงต่อโรคอารมณ์สองขั้ว (Bipolar disor' title='รู้สึกหยุดคิดไม่ได้ คิดถึงแต่เรื่องที่มี'
# [hit] id=382 cat='ระดับฮอร์โมนไทรอยด์ต่ำ (Hypothyroidism)' title='ตอนนี้ขาดประจำเดือน เกือบ 3 เดือนแล้ว สา'
# [  81.5s] next_id=385 last_hit=384 hits=316 processed=383 miss_streak=0 ~4.3 req/s
# [hit] id=353 cat='เสี่ยงต่อโรคทางอารมณ์ที่มีภาวะแทรกซ้อน (' title
cat='เสี่ยงต่อโรคอารมณ์สองขั้ว (Bipolar disor' title='รักษาโรคซึมเศร้ามาประมาณ 1 ปี ถ้าหยุดกิน'
# [hit] id=471 cat='ติดเชื้อชั้นใต้ผิวหนัง (Cellulitis)' title='มีอาการห้อเลือดจากการเล่นกีฬาที่เล็บเท้า'
# [hit] id=475 cat='เสี่ยงต่อโรคทางอารมณ์ที่มีภาวะแทรกซ้อน (' title='รู้สึกว่า5-7เดือนมานี้ ตัวเองแปลกไปจากเด'
# [hit] id=476 cat='ปวดกระบอกตาไม่ทราบสาเหตุ (Ocular pain un' title='มีอาการปวดฟันตรงฟันคุดซ้าย และเหงือกบวมค'
# [hit] id=458 cat='ไข้ชิคุนกุนยา (Chikungunya)' title='ไม่แน่ใจว่าเป็นโรคอะไรค่ะ มีผื่นแดงตามตั'
# [hit] id=478 cat='ซี่โครงอักเสบ (Costochondritis)' title='พอดีคุณยายหกล้มรุนแรงอะครับแล้วหลังจากนั'
# [hit] id=479 cat='เสี่ยงต่อโรคซึมเศร้า (Major depressive d' title='รู้สึกหดหู่ เบื่อหน่าย ไม่อยากทำอะไร ใคร'
# [hit] id=485 cat='เสี่ยงต่อโรคซึมเศร้า (Major depressive d' title='อยากจะไปปรึกษาแพทย์แต่ไม่รู้ว่าจะบอกพ่อแ'
# [hit] id=488 cat='ผิวหนังอักเสบเรื้อรัง (Chronic eczema)' title='บริเวณฝ่ามือและนิ้วมือ มีอาการแพ้มาเป็นเ'
# [  99.6s] next_id=513 last_hit=488 hits=388 processed=485 miss_streak=0 ~6.0 req/s
# [hit] id=490 cat='เต้านมอักเสบ (Mastitis)' title='หนูมีอาการ เจ็บที่หัวนมทั้ง2ข้าง หัวนมเห'
# [hit] id=489 cat='เสี่ยงต่อโรคซึมเศร้า (Major depressive d' title='เหตุผลแรกน่าจะมาจากการผิดหวังจากความรัก '
# [hit] id=491 cat='ริดสีดวงทวาร (Hemorrhoids)' title='มีติ่งเล็กๆอยู่ด้านนอกทวารไ่ม่เจ็บ ไ่ม่ถ'
# [hit] id=483 cat='อาหารเป็นพิษ (Food poisoning)' title='สวัสดีค่ะ มีอาการท้องเสีย อาเจียนหลังจาก'
# [hit] id=497 cat='ข้ออักเสบรูมาตอยด์ (Rheumatoid arthritis' title='แต่มีจุดแดงขึ้นมาถึงปวด'
# [hit] id=487 cat='ภาวะสับสนเฉียบพลัน (Delirium)' title='มีอาการ มึนศรีษะ บางครั้งจะรู้สึกตุบๆในห'
# [hit] id=486 cat='ตาแห้ง (Dry eyes)' title='มีเส้นเลือดในตาขาวขึ้นมาคะไ่ม่แน่ใจว่าเป'
# [hit] id=492 cat='เสี่ยงต่อโรคซึมเศร้า (Major depressive d' title='หนูเบื่ออยากตายทุกวันหาวิธีตายทุกวันหนูค'
# [hit] id=494 cat='เสี่ยงต่อโรคทางอารมณ์ที่มีภาวะแทรกซ้อน (' title='สวัสดีครับ ผมอายุ32 มีปัญหาคืออยู่ๆผมก็ม'
# [hit] id=498 cat='กรดไหลย้อน (GERD)' title='มีอาการแน่นท้อง หลังจากรับประทานอาหารในช'
# [hit] id=493 cat='เสี่ยงต่อโรคซึมเศร้า (Major depressive d' title='ร้องไห้คนเดียวบ่อยมาก ไม่ว่าจะที่บ้านหรื'
# [hit] id=499 cat='ริดสีดวงทวาร (Hemorrhoids)' title='มีรอยย่นๆ ลักษณะเป็นเหมือนติ่งๆ บริเวณขอ'
# [hit] id=496 cat='ภูมิแพ้จมูก (Allergic rhinitis)' title='เนื่องจากตอนนี้อากาศเย็นมากนอกจากการทานย'
# [hit] id=501 cat='ไข้หวัด (Common cold (Nasopharyngitis))' title='สวัสดีค่ะคุณหมอดิฉันเป็นไข้หวัดต้องทานยา'
# [ 102.6s] next_id=513 last_hit=501 hits=402 processed=500 miss_streak=0 ~5.0 req/s
# [hit] id=503 cat='เสี่ยงต่อโรคซึมเศร้า (Major depressive d' title
# [hit] id=6931 cat='การอักเสบของอุ้งเชิงกราน (Pelvic inflamm' title='ฝั่งยาคุมมาระยะ 6 เดือนตั้งแต่พฤษภา มีอา'
# [hit] id=6964 cat='ซิฟิลิส ระยะที่หนึ่ง (Primary syphilis)' title='ผมเพศชายครับ มีอาการสองจุดครับ ปริเวรปลา'
# [ 524.3s] next_id=7041 last_hit=6964 hits=1361 processed=7034 miss_streak=45 ~27.7 req/s
# [hit] id=7000 cat='ภาวะแท้งคุกคาม (Threatened abortion)' title='แฟนผมท้องแล้วได้ไปทำการขูดมดลูกด้วย MVA '
# [hit] id=6997 cat='กรวยไตอักเสบติดเชื้อ (Pyelonephritis)' title='สวัสดีครับคุณหมอ วันที่ 28 กันยายน 2567 '
# [hit] id=6999 cat='ภาวะประจำเดือนมาน้อยผิดปกติ (Oligomenorr' title='ประจำมาน้อยผิดปกติหลายปี ปีหนึ่งเป็นประจ'
# [hit] id=7030 cat='ไข้หวัด (Common cold (Nasopharyngitis))' title='4วันที่แล้วคออักเสบ เมื่อวานคอเเดง กินยา'
# [hit] id=7031 cat='เสี่ยงต่อโรคซึมเศร้า (Major depressive d' title='สวัสดีค่ะ พอดีนอนไม่หลับเลยค่ะ ต้องเพลีย'
# [ 527.3s] next_id=7169 last_hit=7031 hits=1366 processed=7082 miss_streak=42 ~16.0 req/s
# [hit] id=7063 cat='กระดูกสันหลังส่วนเอวเสื่อม (Lumbar spond' title='เจ็บด้านหลัง ขวา สังเกต อาการจะหนักช่วงป'
# [hit] id=7129 cat='เสี่ยงต่อโรคทางอารมณ์ที่มีภาวะแทรกซ้อน (' title='หนูทำงานฟรีเเลนซ์ที่บ้าน ส่วนมากจะนอนอยู'
# [ 530.3s] next_id=7169 last_hit=7129 hits=1368 processed=7165 miss_streak=0 ~27.2 req/s
# [hit] id=7096 cat='เสี่ยงต่อโรคทางอารมณ์ที่มีภาวะแทรกซ้อน (' title='ำมมลำาว่หูป็โคิเท้ยะ'
# [hit] id=7162 cat='หอบหืด (Asthma)' title='ไม่เคยมีประวัติเป็นโรคประจำตัวเเต่มีอากา'
# [hit] id=7195 cat='มะเร็งลำไส้ใหญ่ (Colorectal Cancer)' title='มีอาการขับถ่ายปกติบ้างไม่ปกติบ้าง ท้องด้'
# [hit] id=7196 cat='หูชั้นนอกอักเสบ (Acute otitis externa)' title='มีอาการหูข้างซ้ายอักเสบเป็นๆหายๆ มาประมา'
# [hit] id=7228 cat='ปวดศีรษะไมเกรน (Migraine)' title='ปวดไมเกรนจะปวดกี่ช.มคะ'
# [ 533.3s] next_id=7297 last_hit=7228 hits=1373 processed=7260 miss_streak=7 ~31.8 req/s
# [hit] id=7261 cat='สงสัยภาวะตั้งครรภ์ (Pregnancy not yet co' title='หลังจากประจำเดือนไม่มา14วัน ก็ตรวจไป2ครั'
# [ 536.3s] next_id=7425 last_hit=7261 hits=1374 processed=7353 miss_streak=57 ~31.1 req/s
# [hit] id=7327 cat='หอบหืดกำเริบ (Acute asthmatic attack)' title='น้องอกบุ๋มเเละคอบุ๋มเป็นมา3วันไปหาหมอบอก'
# [hit] id=7360 cat='เสี่ยงต่อโรคซึมเศร้า (Major depressive d' title
cat='เสี่ยงต่อโรคอารมณ์สองขั้ว (Bipolar disor' title='อยากใช้ยารักษาแต่ได้ยินว่ามันไม่ช่วยขนาด'
# [hit] id=7822 cat='เก๊าต์กำเริบ (Acute gouty attack)' title='ผู้ชายนะครับ พอดีเมื่อ 3 วันก่อนไปรักษาอ'
# [ 557.3s] next_id=7937 last_hit=7822 hits=1392 processed=7856 miss_streak=8 ~20.0 req/s
# [hit] id=7889 cat='ภาวะช่องคลอดอักเสบจากเชื้อแบคทีเรีย (Bac' title='คือหนูมีเพศสัมพันธ์ตอนมีประจำเดือนประมาณ'
# [hit] id=7855 cat='เสี่ยงต่อโรคซึมเศร้า (Major depressive d' title='ร้องไห้บ่อยมีอะไรมากระทบจิตใจก็ร้องไห้เค'
# [ 560.4s] next_id=7937 last_hit=7889 hits=1394 processed=7932 miss_streak=22 ~25.2 req/s
# [hit] id=7921 cat='เริมที่อวัยวะเพศ (Genital herpes)' title='ไม่ได้เป็นเริม แต่เป็นเซ็บเดิร์ม ที่เป็น'
# [hit] id=7888 cat='เสี่ยงต่อโรคซึมเศร้า (Major depressive d' title='อยากทราบว่าจะไปหาหมอเรื่องมีอาการป่วยเป็'
# [hit] id=7954 cat='โรคนอนไม่หลับ (Insomnia)' title='เหงื่อออกตอนกลางคืนตามข้อพับ และร้อนที่ห'
# [ 563.4s] next_id=8065 last_hit=7954 hits=1397 processed=8002 miss_streak=14 ~23.2 req/s
# [hit] id=7988 cat='เยื่อบุมดลูกเจริญผิดที่ (Endometriosis)' title='คือหลังจากไปฝังยาคุมมาวันที่ 19 มิ.ย. 67'
# [hit] id=7987 cat='เสี่ยงต่อโรคทางอารมณ์ที่มีภาวะแทรกซ้อน (' title='เสพยาเยอะมีผลต่อสุขภาพในอนาคตเป็นโรคอะไร'
# [hit] id=7990 cat='เสี่ยงต่อโรคทางอารมณ์ที่มีภาวะแทรกซ้อน (' title='คือว่า เวลาไม่ได้ดั่งใจก็คิดแบบจะทำร้ายต'
# [hit] id=8020 cat='ริดสีดวงทวาร ที่มีภาวะแทรกซ้อน (Strangul' title='หนูเป็นคนขับถ่ายยาก แล้ววันนึงหนูรู้สึกเ'
# [ 566.4s] next_id=8193 last_hit=8020 hits=1401 processed=8078 miss_streak=21 ~25.3 req/s
# [hit] id=8119 cat='ปวดศีรษะจากความเครียด (Tension Headache)' title='วิธีคลายเครียดทำยังไง'
# [hit] id=8120 cat='เสี่ยงต่อโรคทางอารมณ์ที่มีภาวะแทรกซ้อน (' title='หมอคนไหนใจดี อยากรักษาหนูคนนี้แบบจริงๆจั'
# [ 569.5s] next_id=8193 last_hit=8120 hits=1403 processed=8176 miss_streak=1 ~31.7 req/s
# [hit] id=8152 cat='หินปูนของหูชั้นในเคลื่อน (Benign paroxys' title='พอดีเกิดอุบัติเหตุรถล้มหัวกระแทกพื้น ผ่า'
# [hit] id=8186 cat='หลอดลมอักเสบ (Acute Bronchitis)' title='พอดีไปหาหมอมา หมอวินิจฉัยว่าป่วยเป็นไข้ห'
# [hit] id=8185 cat='หอบหืด (Asthma)' title='พอดีไปหาหมอมา หมอวินิจฉัยว่าป่วยเป็นไข้ห'
# [ 572.5s] next_id=8321 last_hit=8186 hits=1406 processed=8253 miss_streak=61 ~25.7 req/s
# [hit] id=8218 cat='ไข้เลือดออกที่มีอาการรุนแรง (Dengue hemo' title='ไม่เเน่ใจว่าใช่โรคไข้เลือดออกมั้ย เเค่หน'
# [ 575.5s] next_id=8321 last_hit=8218 hits=1407 processed=8259 miss_streak=0 ~2.0 req/s
# [hit] id=8251 cat='ภาวะการปรับตัวผิดปกติ (Adjustment disord' title='การที่หนูรู้สึกว่าพักหลังๆมานี้พฤติกรรมข'
# [ 578.5s] next_id=8321 last_hit=8251 hits=1408 processed=8315 miss_streak=42 ~18.6 req/s
# [hit] id=8284 cat='อ่อนเพลียทั่วไป (Fatigue unspecified)' title='มีอาการเบื่ออาหาร ปวดหัวบ้างนานๆครั้ง มี'
# [hit] id=8317 cat='ริดสีดวงทวาร (Hemorrhoids)' title='มีแผลลถลอกที่อวัยวะเพศชายแล้ววมีเพศสัมพั'
# [hit] id=8350 cat='ตามัวไม่ทราบสาเหตุ (Blurry vision unspec' title='ปกติเป็นคนตาแห้งอยู่แล้วค่ะ แต่ช่วงนี้บา'
# [ 581.5s] next_id=8449 last_hit=8350 hits=1411 processed=8393 miss_streak=3 ~26.0 req/s
# [hit] id=8383 cat='อัณฑะอักเสบ (Epididymo-orchitis)' title='มีอาการจุก ปวดที่อัณฑะข้างขวา และปวดท้อง'
# [ 584.5s] next_id=8577 last_hit=8383 hits=1412 processed=8489 miss_streak=48 ~31.8 req/s
# [hit] id=8449 cat='เสี่ยงต่อโรคซึมเศร้า (Major depressive d' title='พ่อไล่ไปตาย ด่า ตบหน้า ทำร้ายร่างกาย'
# [hit] id=8482 cat='ผื่นตามร่างกาย (Dermatitis unspecified)' title='คุณหมอคะ มีอาการเป็นผื่นคันเกิดขึ้นโดยไม'
# [ 587.5s] next_id=8577 last_hit=8482 hits=1414 processed=8575 miss_streak=19 ~28.7 req/s
# [hit] id=8548 cat='ชักเกร็ง' title='มีอาการเริ่มชักเกร็งหลังร้องไห้หนัก แล้ว'
# [hit] id=8581 cat='กล้ามเนื้ออักเสบบริเวณคอ บ่า ไหล่' title='มีอาการโคลงเคลงเหมือนอยู่บนเรือตลอด มีลม'
# [ 590.5s] next_id=8705 last_hit=8581 hits=1416 processed=8659 miss_streak=26 ~28.1 req/s
# [hit] id=8647 cat='หูดหงอนไก่' title='มันเป็นตุ่มเล็กๆตรงบริเวณที่ผมเลือกรูปไป'
# [hit] id=8614 cat='เสี่ยงต่อโรคทางอารมณ์ที่มีภาวะแทรกซ้อน' title='หนูรู้สึกว่าตัวเองกลัวทุกอย่าง มีอะไรนิด'
# [hit] id=8680 cat='ภาวะเลือดออกผิดปกติจากโพรงมดลูก' title='สวัสดีค่ะ หนูเพิ่งแท้งลูกไปเมื่อวันที่9ม'
# [ 593.5s] next_id=8833 last_hit=8680 hits=1419 processed=8747 miss_streak=43 ~29.3 req/s
# [hit] id=8713 cat='ก้อนของต่อมไทรอยด์' title='สวัสดีค่ะคุณหมอหนูมีอาการเจ็บบริเวณใต้โค'
# [hit] id=8746 cat='ภาวะเลือดออกผิดปกติจากโพรงมดลูก' title='ลูกอายุ 10 ขวบ 8 เดือน เป็นประจำเดือนครั'
# [hit] id=8779 cat='เสี่ยงต่อโรคซึมเศร้า' title='แล้วหนูต้องทำยังไงคะ ตอนนี้ปวดหัวมากๆ 😭'
# [ 596.5s] next_id=8833 last_hit=8779 hits=1422 processed=8831 miss_streak=24 ~27.9 req/s
# [hit] id=8812 cat='กล้ามเนื้ออักเสบบริเวณคอ บ่า ไหล่' title='สวัสดีค่ะ พอดีปวดท้ายทอยต้นคอ มันปวดจนทำ'
# [hit] id=8845 cat='ภาวะการปรับตัวผิดปกติ' title='ประจำเดือนมาไม่ปกติ ซึ่งทุกครั้งที่ มีเพ'
# [ 599.6s] next_id=8961 last_hit=8845 hits=1424 processed=8911 miss_streak=0 ~26.4 req/s
# [hit] id=8878 cat='เยื่อบุตาอักเสบ' title='ตาแดง แสบตา เคืองตา กดเปลือกตาแล้วเจ็บ ท'
# [hit] id=8911 cat='ก้อนที่คอไม่ทราบสาเหตุ' title='คลำที่คอแล้วเจอก้อน ที่คอด้านหน้า กดที่ก'
# [hit] id=8944 cat='ไข้หวัด' title='อยากสอบถามอาการของลูกค่ะ น้อง7ขวบกว่ามีไ'
# [ 602.6s] next_id=9089 last_hit=8944 hits=1427 processed=8996 miss_streak=36 ~28.4 req/s
# [hit] id=9010 cat='น้ำตาลในเลือดต่ำ' title='สวัสดีค่ะ มีอาการเจ็บแสบหน้าอกเหมือนหัวใ'
# [ 605.5s] next_id=9089 last_hit=9010 hits=1428 processed=9078 miss_streak=20 ~27.4 req/s
# [hit] id=9044 cat='ภาวะการปรับตัวผิดปกติ' title='สวัสดีค่ะ มีอาการคล้ายไฟตกในตาแวบเดียวแล'
# [hit] id=9043 cat='ภาวะการปรับตัวผิดปกติ' title='มีพฤติกรรมก้าวร้าวบางครั้ง ท้อแท้ ไร้ค่า'
# [hit] id=9045 cat='กระเพาะอาหารอักเสบ' title='รักษายังไงหรอครับให้หายขาด'
# [hit] id=9076 cat='หมอนรองกระดูกส่วนเอวปลิ้น (Herniated nuc' title='Acoxia90mg กินแล้วอาการปวดดีขึ้นได้ประมา'
# [hit] id=9109 cat='ไข้หวัด' title='ปวดหัว ไม่มากครับ ตัวร้อนไม่เยอะ ตัดจมูก'
# [ 608.6s] next_id=9217 last_hit=9109 hits=1433 processed=9149 miss_streak=0 ~23.5 req/s
# [hit] id=9110 cat='ลำไส้อักเสบติดเชื้อ' title='ต้องทานยาอะไร'
# [hit] id=9143 cat='ระดับฮอร์โมนไทรอยด์ต่ำ' title='อันตรายมากแค่ไหน'
# [hit] id=9142 cat='ภาวะแท้งคุกคาม' title='ลิ่มเลือดขนาดใหญ่เกี่ยวด้วยมั้ยคะแบบนี้จ'
# [hit] id=9175 cat='ไข้หวัด' title='ต้องการขอรับยา'
# [hit] id=9208 cat='ปวดข้อทั่วไป' title='เจ็บบริเวณข้อนิ้วก้อยเท้าเล็กน้อย ใกล้กั'
# [ 611.5s] next_id=9345 last_hit=9208 hits=1438 processed=9216 miss_streak=0 ~22.5 req/s
# [hit] id=9241 cat='หัวใจขาดเลือดเฉียบพลัน' title='สามารถรักษาให้หายปกติได้มั้ยคะ'
# [ 614.6s] next_id=9345 last_hit=9241 hits=1439 processed=9313 miss_streak=34 ~32.2 req/s
# [hit] id=9274 cat='ภาวะท้องนอกมดลูก' title='มีตกขาวมามากค่ะไม่คันไม่มีกลิ่น ปจด.ขาด '
# [hit] id=9340 cat='ภาวะผิดปกติทางทันตกรรม' title='ผมมีกลิ่นปากเหม็นจนคนใกล้ตัวทักครับเหม็ก'
# [hit] id=9307 cat='หลอดลมอักเสบ' title='ประเทศไทยควรดำเนินการทางกรทูตเชิงรุกกับก'
# [ 617.5s] next_id=9473 last_hit=9340 hits=1442 processed=9348 miss_streak=4 ~11.7 req/s
# [hit] id=9373 cat='เสี่ยงต่อโรคอารมณ์สองขั้ว' title='ต้องรักษาแบบไหนครับ ผมเพิ่งเลิกกับแฟน ผม'
# [ 620.6s] next_id=9473 last_hit=9373 hits=1443 processed=9434 miss_streak=18 ~28.6 req/s
# [hit] id=9406 cat='ผื่นผิวหนังอักเสบจากการแพ้' title='ก่อนหน้าเคยรักษากับหมอผิวหนังเขาบอกว่าเป'
# [ 623.6s] next_id=9473 last_hit=9406 hits=1444 processed=9470 miss_streak=25 ~12.0 req/s
# [hit] id=9472 cat='ริดสีดวงทวาร ที่มีภาวะแทรกซ้อน' title='ยังมีถ่ายปนเลือดมา2 อาทิตย์แล้ว แต่เลือด'
# [hit] id=9439 cat='เสี่ยงต่อโรคซึมเศร้า' title='จะต้องรักษายังไงบ้างคะ'
# [ 626.6s] next_id=9601 last_hit=9472 hits=1446 processed=9544 miss_streak=72 ~24.6 req/s
# [hit] id=9538 cat='เสี่ยงต่อโรคซึมเศร้า' title='รู้สึก​โดดเดี่ยว​ไม่มีใครเข้า​ใจทะเลาะ​ก'
# [hit] id=9571 cat='คอหอยอักเสบ' title='คือ อาการมันไม่มีในตัวเลือก ไม่รุ้ว่าตั้'
# [ 629.6s] next_id=9729 last_hit=9571 hits=1448 processed=9619 miss_streak=19 ~25.0 req/s
# [hit] id=9604 cat='เสี่ยงต่อโรคทางอารมณ์ที่มีภาวะแทรกซ้อน' title='ทำไทำไมความรู้สึกว่างเปล่าไม่สามารถโฟกัส'
# [hit] id=9638 cat='ภาวะการปรับตัวผิดปกติ' title='คือหนูเคยโดนทำร้ายร่างกาย แล้วทุกวันนี้ก'
# [hit] id=9637 cat='เสี่ยงต่อโรคซึมเศร้า' title='คือไม่อยากทำอะไรเลย เบื่อหน่ายหมดไฟหมดกำ'
# [ 632.6s] next_id=9729 last_hit=9638 hits=1451 processed=9702 miss_streak=32 ~27.6 req/s
# [hit] id=9670 cat='ข้อไหล่ติด' title='เส้นเอ็นมีปัญหาใช่ไหม'
# [hit] id=9703 cat='ไซนัสอักเสบ' title='เราได่รับยาฏ่าเชืัอแบบแรง วีฟรอก750มก. ม'
# [ 635.6s] next_id=9857 last_hit=9703 hits=1453 processed=9779 miss_streak=55 ~25.6 req/s
# [hit] id=9736 cat='ไข้หวัด' title='สวัสดีครั พอดว่าแฟผมได้กลิ่นกรหายใจของผม'
# [hit] id=9769 cat='หลอดลมอักเสบ' title='มีอาการมานานเป็นสัปดาห์แล้วแต่ไม่หาย'
# [hit] id=9803 cat='ผิวหนังอักเสบเรื้อรัง' title='คือเป็นรอยจุดเล็กๆ แดงจางๆ บริเวณหน้าอกม'
# [hit] id=9802 cat='ภาวะการปรับตัวผิดปกติ' title='เหงื่อออกมือและเท้าเยอะผิดปกติครับ'
# [ 638.6s] next_id=9857 last_hit=9803 hits=1457 processed=9855 miss_streak=16 ~25.1 req/s
# [hit] id=9835 cat='ลำไส้อักเสบ' title='Hiv เกี่ยวมั้ยครับ'
# [hit] id=9868 cat='ออฟฟิศซินโดรม' title='อาการปวดหัวเป็นติดต่อกันหลายวัน กินยาบรร'
# [ 641.6s] next_id=9985 last_hit=9868 hits=1459 processed=9936 miss_streak=27 ~27.1 req/s
# [hit] id=9901 cat='ระดับฮอร์โมนไทรอยด์ต่ำ' title='ผมร่วงหนักมากค่ะ ควรไปรักษาไหมคะ เกิดจาก'
# [hit] id=9934 cat='เยื่อบุมดลูกเจริญผิดที่' title='เท่าที่สังเกตอาการตัวเองมาตั้งแต่เดือนเม'
# [hit] id=9935 cat='ผื่นตามร่างกาย' title='พอดีว่า เป็นขุยๆขาวๆ ลอกแล้วแสบมากเลยค่ะ'
# [hit] id=9967 cat='เสี่ยงต่อโรคอารมณ์สองขั้ว' title='คือโรคอะไรคะไม่เคยได้ยินแล้วควรไปพบจิตแพ'
# [ 644.6s] next_id=10113 last_hit=9967 hits=1463 processed=10009 miss_streak=25 ~24.3 req/s
# [hit] id=10000 cat='เสี่ยงต่อโรคอารมณ์สองขั้ว' title='สวัสดีครับ คือส่วนตัวไปพบหมอและได้รับการ'
# [hit] id=10034 cat='ผื่นตามร่างกาย' title='อากาศร้อน เหงื่อออก มีผื่นแดงขึ้นทั้งขึ้'
# [hit] id=10033 cat='เชื้อราในช่องคลอด' title='มีการรักษาด้วยการสอดยา หายคันค่ะ แต่วันแ'
# [ 647.6s] next_id=10113 last_hit=10034 hits=1466 processed=10108 miss_streak=36 ~33.0 req/s
# [ 650.6s] next_id=10241 last_hit=10034 hits=1466 processed=10215 miss_streak=143 ~35.7 req/s
# [ 653.6s] next_id=10335 last_hit=10034 hits=1466 processed=10266 miss_streak=194 ~17.0 req/s
# [ 656.6s] next_id=10335 last_hit=10034 hits=1466 processed=10334 miss_streak=262 ~22.7 req/s
#
# Found 1466 threads in 656.6s.
# ID range covered: 1 → 10034
# Sample row:
# {
#   "url": "https://www.agnoshealth.com/forums/1",
#   "thread_id": "1",
#   "title": "เป็นคล้ายๆผดผื่นที่ก้นค่ะน้อง9เดือน ผดนูนขุขระ",
#   "thread_category": "ผื่นตามร่างกาย (Dermatitis unspecified)",
#   "answer_by_doctor": "ผดผื่นที่ก้นเด็กมักเกิดจากความอับชื้น หรือการระคายเคืองจากสารระคายเคืองต่างๆ เช่น แป้ง สบู่ หรือผงซักฟอก แนะนำให้ดูแลเรื่องความสะอาดและป้องกันความอับชื้นบริเวณก้นและขาหนีบ อาจพิจารณาเปลี่ยนผลิตภัณฑ์ทำความสะอาด แพมเพิร์ส หรือผงซักฟอกให้เป็นสูตรที่ลดการระคายเคือง หรือสูตรสำหรับผิวแพ้ง่าย อาการจะค่อยๆดีขึ้นครับ",
#   "title_category": "เป็นคล้ายๆผดผื่นที่ก้นค่ะน้อง9เดือน ผดนูนขุขระ ผื่นตามร่างกาย (Dermatitis unspecified)"
# }
#
# Saved JSON: agnos_forum_threads.json
# Saved CSV : agnos_forum_threads.csv
